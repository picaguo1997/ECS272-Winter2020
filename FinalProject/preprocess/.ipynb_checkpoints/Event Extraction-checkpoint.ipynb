# %%
import json 
from datetime import datetime
import matplotlib.pyplot as plt
from textblob import TextBlob
from collections import Counter
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import sklearn
import numpy as np
from wordcloud import WordCloud

from datetime import datetime
from dateutil.parser import parse

# %% [markdown]
# ### Load Data

# %%
data_path_bbc = './bbc.json'
data_path_wp = './washington_post.json'
data_path_fox = './fox.json'
data_path_bb = './breitbart.json'

# %%
with open(data_path_bbc) as json_file:
    data_bbc = json.load(json_file)
    
with open(data_path_wp) as json_file:
    data_wp = json.load(json_file) 
    
with open(data_path_fox) as json_file:
    data_fox = json.load(json_file) 
    
with open(data_path_bb) as json_file:
    data_bb = json.load(json_file) 
    
data = data_bbc + data_wp + data_fox + data_bb

# %%
articles_per_date = {}

for article in data:
    dt = parse(article['time-stamp'])
    
    if dt.year != 2020:
        continue
    
    if not dt.date() in articles_per_date:
        articles_per_date[dt.date()] = []
    
    articles_per_date[dt.date()].append(article)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/dateutil/parser/_parser.py:1213: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
x = []
y = []
for key in articles_per_date:
    x.append(key)
    y.append(len(articles_per_date[key]))
    
xx = range(0,len(y))

# %%
print(y)
print(x)
# Out:
# [54, 17, 26, 7, 14, 11, 11, 10, 9, 52, 12, 7, 23, 5, 1, 5, 8, 7, 14, 8, 3, 4, 10, 16, 27, 7, 5, 14, 3, 9, 6, 4, 4, 3, 3, 1, 1, 53, 5, 75, 1, 2, 7]
# [datetime.date(2020, 2, 21), datetime.date(2020, 1, 28), datetime.date(2020, 1, 30), datetime.date(2020, 1, 24), datetime.date(2020, 1, 31), datetime.date(2020, 1, 22), datetime.date(2020, 2, 13), datetime.date(2020, 2, 10), datetime.date(2020, 2, 20), datetime.date(2020, 2, 25), datetime.date(2020, 2, 23), datetime.date(2020, 1, 25), datetime.date(2020, 1, 29), datetime.date(2020, 2, 18), datetime.date(2020, 1, 19), datetime.date(2020, 2, 2), datetime.date(2020, 2, 4), datetime.date(2020, 2, 5), datetime.date(2020, 1, 23), datetime.date(2020, 2, 6), datetime.date(2020, 2, 9), datetime.date(2020, 1, 26), datetime.date(2020, 2, 3), datetime.date(2020, 1, 27), datetime.date(2020, 2, 24), datetime.date(2020, 2, 11), datetime.date(2020, 2, 17), datetime.date(2020, 2, 7), datetime.date(2020, 2, 8), datetime.date(2020, 2, 12), datetime.date(2020, 2, 14), datetime.date(2020, 2, 19), datetime.date(2020, 1, 21), datetime.date(2020, 1, 20), datetime.date(2020, 2, 1), datetime.date(2020, 1, 18), datetime.date(2020, 1, 9), datetime.date(2020, 2, 26), datetime.date(2020, 2, 22), datetime.date(2020, 2, 27), datetime.date(2020, 2, 16), datetime.date(2020, 2, 15), datetime.date(2020, 2, 28)]

# %%
plt.figure(figsize=(12,8))
plt.plot(xx, y)
plt.show()
plt.figure(figsize=(12,8))
plt.bar(x, y)
plt.show()

# %%
for a in articles_per_date[datetime(2020,2,26).date()]:
    print(a['headline'])
# Out:
# Coronavirus concerns on New York's Long Island see 83 being monitored
# American, Delta and United Airlines offering waivers for travel to South Korea amid coronavirus outbreak
# Trump says coronavirus vaccine coming along 'rapidly,' appoints Pence to head task force
# Melissa Francis: Americans will be 'very frustrated' if coronavirus becomes politicized
# Traveling amid the coronavirus outbreak: What you need to know
