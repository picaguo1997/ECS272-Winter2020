# %% [markdown]
# ## Imports

# %%
import urllib
from selectolax.parser import HTMLParser
from dateutil.parser import parse

# %%
from framework.crawler import Crawler
from framework.newssource import NewsSource

# Right
from framework.newssources.foxnews import FoxNews
from framework.newssources.breitbart import Breitbart

# Central
from framework.newssources.abcnews import ABCNews
from framework.newssources.cnn import CNN


# Left
from framework.newssources.washingtonpost import WashingtonPost
from framework.newssources.newyorktimes import NewsSource

# %% [markdown]
# ## Scraping

# %%
keywords = [
    'corona',
    'Corona',
    'coronavirus',
    'Coronavirus',
]

depth = 5

# %%
crawler = Crawler(keywords, depth)

# %%
url = 'https://abcnews.go.com/Health/timeline-coronavirus-started/story?id=69435165'
scraper = ABCNews(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# https://abcnews.go.com/Health/timeline-coronavirus-started/story?id=69435165
# crawling 1 / 5
# crawling 2 / 5
# crawling 3 / 5
# crawling 4 / 5
# crawling 5 / 5
# Crawling done
# Filtering links...
# Done.
# Scraping 30 sources on ABC News
# https://abcnews.go.com/Health/coronavirus-live-updates-american-tourist-1st-confirmed-case/story?id=69429757
# 1 / 30 https://abcnews.go.com/Health/coronavirus-live-updates-american-tourist-1st-confirmed-case/story?id=69429757
# https://abcnews.go.com/Health/pandemic-coronavirus/story?id=68746843
# 2 / 30 https://abcnews.go.com/Health/pandemic-coronavirus/story?id=68746843
# https://abcnews.go.com/International/23-americans-aboard-cruise-ship-japan-contract-coronavirus/story?id=68879743
# 3 / 30 https://abcnews.go.com/International/23-americans-aboard-cruise-ship-japan-contract-coronavirus/story?id=68879743
# https://abcnews.go.com/Health/timeline-coronavirus-started/story?id=69435165
# ...

# %%
scraper.get_output()[0]
# Out:
# {'content': ['\nMore than 95,000 people around the world have been infected by an outbreak of the novel coronavirus, and more than 3,200 have died.\n',
#   '\nThe newly identified virus was first detected in December in Wuhan, China, the epicenter of the global outbreak. The virus, known officially as COVID-19, has since spread to every continent except Antarctica, and the World Health Organization has declared the outbreak a global health emergency. South Korea, Italy and Iran have the highest national totals of confirmed cases behind China, respectively.\n',
# ...
