# %% [markdown]
# ## Imports

# %%
import urllib
from selectolax.parser import HTMLParser
from dateutil.parser import parse

# %%
from framework.crawler import Crawler
from framework.newssource import NewsSource

# Right
from framework.newssources.foxnews import FoxNews
from framework.newssources.breitbart import Breitbart

# Central
from framework.newssources.abcnews import ABCNews
from framework.newssources.cnn import CNN


# Left
from framework.newssources.washingtonpost import WashingtonPost
from framework.newssources.newyorktimes import NewYorkTimes

# %% [markdown]
# ## Scraping

# %%
keywords = [
    'COVID',
    'covid',
    'Covid',
    'COVID-19',
    'covid-19',
    'Covid-19',
    'COVID19',
    'covid19',
    'Covid19'
    'SARS-CoV-2'
    'Coronavirus',
    'coronavirus',
]

depth = 500

# %%
crawler = Crawler(keywords, depth)

# %% [markdown]
# ### FOX

# %%
url = 'https://www.foxnews.com/category/health/infectious-disease/coronavirus'
scraper = FoxNews(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# https://www.foxnews.com/category/health/infectious-disease/coronavirus
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# crawling 39 / 500
# crawling 40 / 500
# crawling 41 / 500
# crawling 42 / 500
# crawling 43 / 500
# crawling 44 / 500
# ...

# %% [markdown]
# ### Breitbart

# %%
url = 'https://www.breitbart.com/tag/coronavirus/'
scraper = Breitbart(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# https://www.breitbart.com/tag/coronavirus/
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# crawling 39 / 500
# crawling 40 / 500
# crawling 41 / 500
# crawling 42 / 500
# crawling 43 / 500
# crawling 44 / 500
# crawling 45 / 500
# crawling 46 / 500
# ...

# %% [markdown]
# ### ABC

# %%
url = 'https://abcnews.go.com/Health/timeline-coronavirus-started/story?id=69435165'
scraper = ABCNews(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# https://abcnews.go.com/Health/timeline-coronavirus-started/story?id=69435165
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# crawling 39 / 500
# crawling 40 / 500
# crawling 41 / 500
# crawling 42 / 500
# crawling 43 / 500
# crawling 44 / 500
# ...

# %% [markdown]
# ### CNN

# %%
url = 'https://www.cnn.com/2020/03/09/us/coronavirus-university-college-classes/index.html'
scraper = CNN(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# https://www.cnn.com/2020/03/09/us/coronavirus-university-college-classes/index.html
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# crawling 39 / 500
# crawling 40 / 500
# crawling 41 / 500
# crawling 42 / 500
# crawling 43 / 500
# crawling 44 / 500
# ...

# %% [markdown]
# ### Washington Post

# %%
url = 'https://www.washingtonpost.com/world/2020/03/09/coronavirus-live-updates/?rand=9'
scraper = WashingtonPost(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# https://www.washingtonpost.com/world/2020/03/09/coronavirus-live-updates/?rand=9
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# crawling 39 / 500
# crawling 40 / 500
# crawling 41 / 500
# crawling 42 / 500
# crawling 43 / 500
# crawling 44 / 500
# ...

# %% [markdown]
# ### New York Times

# %%
url = 'https://www.nytimes.com/2020/03/09/world/coronavirus-news.html'
scraper = NewYorkTimes(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# https://www.nytimes.com/2020/03/09/world/coronavirus-news.html
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# crawling 39 / 500
# crawling 40 / 500
# crawling 41 / 500
# crawling 42 / 500
# crawling 43 / 500
# crawling 44 / 500
# crawling 45 / 500
# ...

# %%
len(scraper.get_output())
# Out:
# 73
