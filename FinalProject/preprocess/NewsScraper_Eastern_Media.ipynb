# %% [markdown]
# ## Imports

# %%
import urllib
from selectolax.parser import HTMLParser
from dateutil.parser import parse

# %%
from framework.crawler import Crawler
from framework.newssource import NewsSource

from framework.newssources.people import People
from framework.newssources.xinhua import Xinhua
from framework.newssources.ecns import ECNS
from framework.newssources.cgtn import CGTN

from framework.newssources.cctv import CCTV
from framework.newssources.eastday import Eastday
from framework.newssources.chinadaily import Chinadaily

# %% [markdown]
# ## Scraping

# %%
keywords = [
    'COVID',
    'covid',
    'Covid',
    'COVID-19',
    'covid-19',
    'Covid-19',
    'COVID19',
    'covid19',
    'Covid19'
    'SARS-CoV-2'
    'Coronavirus',
    'coronavirus',
]

depth = 500

# %%
crawler = Crawler(keywords, depth)

# %% [markdown]
# ## CGTN 中國環球電視網

# %%
#the link is english
url = 'https://www.cgtn.com/'
scraper = CGTN(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# https://www.cgtn.com/
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# crawling 39 / 500
# crawling 40 / 500
# crawling 41 / 500
# crawling 42 / 500
# crawling 43 / 500
# crawling 44 / 500
# crawling 45 / 500
# crawling 46 / 500
# crawling 47 / 500
# ...

# %% [markdown]
# ## ECNS 中國新聞網

# %%
url = 'http://www.ecns.cn/'
scraper = ECNS(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# http://www.ecns.cn/
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# crawling 39 / 500
# crawling 40 / 500
# crawling 41 / 500
# crawling 42 / 500
# crawling 43 / 500
# crawling 44 / 500
# crawling 45 / 500
# crawling 46 / 500
# crawling 47 / 500
# ...

# %% [markdown]
# ## ChinaDaily 中國日報

# %%
url = 'http://www.chinadaily.com.cn/world'
scraper = Chinadaily(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# http://www.chinadaily.com.cn/world
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# Crawling done
# Filtering links...
# Done.
# Scraping 35 sources on ChinaDaily
# 1 / 35 http://www.chinadaily.com.cn/a/202003/04/WS5e5f7327a31012821727c4f3.html?
# ...

# %% [markdown]
# ## Eastday 東方

# %%
url = 'http://english.eastday.com/World/index.html'
scraper = Eastday(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# http://english.eastday.com/World/index.html
# crawling 1 / 50
# Over 50 countries, regions outside China see local transmission of COVID-19: WHO
# Italy locks down wealthy northern region to contain coronavirus
# LatAm countries take measures to prevent COVID-19 spread as first death reported
# New York governor declares state of emergency as COVID-19 cases soar to 76 statewide
# Feature: Overseas Chinese donate medical supplies to coronavirus-affected German town
# Indian PM holds review meeting on COVID-19 situation with 3 new cases reported
# Asia-Pacific countries report more COVID-19 cases with S.Korea confirming 274 cases in a day
# Japan reports 63 more cases of COVID-19, 1,137 in total
# Over 300 COVID-19 cases confirmed in U.S., with 21 new ones from California cruise ship
# "No reason for panic" over coronavirus, Brazilian president says
# ...

# %% [markdown]
# ## CCTV 央視

# %%
#url = 'http://so.cntv.cn/language/english/index.php?qtext=covid-19&type=1&sort=SCORE&page=1&vtime=-1&datepid=1&history=yes'
#url = 'http://english.cctv.com/2020/03/10/ARTINIZ1kTN2FohMttP2G8Jb200310.shtml'
url = 'http://english.cctv.com/'
scraper = CCTV(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# http://english.cctv.com/
# crawling 1 / 500
# Moment of truth: Xi leads war against COVID-19
# China to deepen int'l cooperation on COVID-19 prevention, control
# Over 4,000 people die of COVID-19 as global cases surpass 110,000: WHO
# Italy under lockdown to fight coronavirus
# Victory in sight for the Chinese people led by Xi Jinping in their war on COVID-19
# China condemns U.S. practice of stigmatization with novel coronavirus: spokesperson
# WHO chief says South Korea, Italy, Iran, Japan greatest concern for COVID-19
# China fights against novel coronavirus
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# Since the outbreak of the COVID-19 epidemic, China has taken comprehensive, strenuous and thorough measures that are now showing results. The international community highly appreciates the efforts and is willing to work with China to overcome difficulties.
# ...

# %% [markdown]
# ## Xinhua 新華

# %%
url = 'http://www.xinhuanet.com/english/special/2020coronavirus/latest.htm'
scraper = Xinhua(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# http://www.xinhuanet.com/english/special/2020coronavirus/latest.htm
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# crawling 39 / 500
# crawling 40 / 500
# crawling 41 / 500
# crawling 42 / 500
# crawling 43 / 500
# crawling 44 / 500
# crawling 45 / 500
# ...

# %% [markdown]
# ## People 人民網

# %%
url = 'http://en.people.cn/90777/index.html'
scraper = People(url, crawler)
scraper.run()
# Out:
# Crawling for sources using seed...
# http://en.people.cn/90777/index.html
# crawling 1 / 500
# crawling 2 / 500
# crawling 3 / 500
# crawling 4 / 500
# crawling 5 / 500
# crawling 6 / 500
# crawling 7 / 500
# crawling 8 / 500
# crawling 9 / 500
# crawling 10 / 500
# crawling 11 / 500
# crawling 12 / 500
# crawling 13 / 500
# crawling 14 / 500
# crawling 15 / 500
# crawling 16 / 500
# crawling 17 / 500
# crawling 18 / 500
# crawling 19 / 500
# crawling 20 / 500
# crawling 21 / 500
# crawling 22 / 500
# crawling 23 / 500
# crawling 24 / 500
# crawling 25 / 500
# crawling 26 / 500
# crawling 27 / 500
# crawling 28 / 500
# crawling 29 / 500
# crawling 30 / 500
# crawling 31 / 500
# crawling 32 / 500
# crawling 33 / 500
# crawling 34 / 500
# crawling 35 / 500
# crawling 36 / 500
# crawling 37 / 500
# crawling 38 / 500
# crawling 39 / 500
# crawling 40 / 500
# crawling 41 / 500
# crawling 42 / 500
# crawling 43 / 500
# crawling 44 / 500
# crawling 45 / 500
# crawling 46 / 500
# ...
